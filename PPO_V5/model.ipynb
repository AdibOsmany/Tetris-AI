# %% [markdown]
# # INSTALLATIONS

# %%
# !pip3 install gym
# !pip3 install easyocr
# !pip3 install torch torchvision torchaudio
# !pip3 install stable-baselines3
# !pip3 install shimmy

# %% [markdown]
# # BACK END

# %% [markdown]
# ## Imports

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Box, Dict
import numpy as np
import random
import time
import easyocr
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import pyautogui as pag
from PIL import Image
from collections import OrderedDict

# %% [markdown]
# ## Paths

# %%
log_path = os.path.join('Training', 'Logs')
save_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Tetris')

# %% [markdown]
# ## Get Stats

# %%
def readImg(img):
    reader=easyocr.Reader(['en'], gpu=False)
    result=reader.readtext(img)
    if len(result)==0:
        return 0
    elif (not result[0][1].isdigit()):
        return 0
    output=result[0][1]
    return int(output)
    
#get the score 
def getScore():
    pag.screenshot('score.png',region=(626,875, 300, 28))
    return readImg('score.png')
    
#of lines
def getLine():
    pag.screenshot('line.png',region=(626,903, 300, 28))
    return readImg('line.png')

#of Blocks
def getBlocks():
    pag.screenshot('blocks.png',region=(626,931, 300, 28))
    return readImg('blocks.png')

# %% [markdown]
# ## Movements

# %%
L_BLOCK = (227,91,2)
J_BLOCK = (33,65,198)
T_BLOCK = (175,41,138)
O_BLOCK = (227,159,2)
S_BLOCK = (89,177,1)
Z_BLOCK = (215,15,55)

BLOCKS=[J_BLOCK,L_BLOCK,O_BLOCK,T_BLOCK,S_BLOCK,Z_BLOCK]

#rotate counter clock wise
def rotateCC():
    pag.keyDown('z')
    pag.keyUp('z')


#rotate clockwise
def rotateCW():
    pag.keyDown('up')
    pag.keyUp('up')


#soft drop
def softDrop():
    pag.keyDown('down')
    pag.keyUp('down')


#hard drop
def hardDrop():
    pag.keyDown('space')
    pag.keyUp('space')


#move right
def right():
    pag.keyDown('right')
    pag.keyUp('right')



#move left
def left():
    pag.keyDown('left')
    pag.keyUp('left')


#new game
#Point(x=913, y=670)   
def newGame():
    pag.FAILSAFE=True
    pag.moveTo(913,670)
    pag.click()


def checkDone():
    return (not pag.pixelMatchesColor(915,650,(0,0,0)))


def getTetromino(piece = 1):
    tetromino= pag.pixel(869,108+(piece*100))
    if tetromino in BLOCKS:
        return BLOCKS.index(tetromino) + 1
    return 7

    # No Piece [J_BLOCK, L_BLOCK, O_BLOCK, T_BLOCK, S_BLOCK, Z_BLOCK, I_BLOCK]
    #   0         1        2        3        4        5        6        7   


#hold key
def hold():
    pag.keyDown('c')
    pag.keyUp('c')

# %% [markdown]
# ## Canvas

# %%
        self.observation_space = Dict({'Current': Discrete(8), 'Next':Discrete(8), 'Hold':Discrete(8), 'Board':Box(0,1, shape=(20,10), dtype= int)})
        self.state=OrderedDict(sorted({'Current': 0, 'Next': 0, 'Hold': 0, 'Board': np.reshape([[0]*10]*20, (20,10))}.items()))
        self.empty=True
        self.held=False
        self.nextPiece2=0

    def step(self, action):

        reward=0
        #apply actions
        ACTIONS[action]()
        if action==5:
            if self.empty:
                self.state['Hold']=self.state['Current']
                self.state['Current']=self.state['Next']
                self.state['Next']=getTetromino()
                self.nextPiece2=getTetromino(piece=2)
                self.empty=False
                self.held=True

            elif self.held==False:
                temp=self.state['Current']
                self.state['Current']=self.state['Hold']
                self.state['Hold']=temp
                self.held=True
        
        #update board
        self.state['Board']=boardState()

        #update current and next piece
        next=getTetromino()
        next2=getTetromino(piece=2)
        if ((self.state['Next'] != next) or (self.nextPiece2 != next2)): 
            self.state['Current']=self.state['Next']
            self.state['Next']=next
            self.nextPiece2=next2
            self.held=False
        


        #check if done
        done=checkDone()
        if done:
            reward= (getLine()*10)+(getBlocks())

        #set placeholder
        info={}

        #return stuff
        return self.state, reward, done, info

        
    def render(self):
        pass

    def reset(self):
        newGame()
        self.state= {'Current': getTetromino(), 'Hold': 0}
        self.empty=True
        self.held=False
        time.sleep(2.5)
        self.state['Board']=boardState()
        self.state['Next']= getTetromino()
        self.nextPiece2=getTetromino(piece=2)
        self.state=OrderedDict(sorted(self.state.items()))
        return self.state

# %%
env= tetrisEnv()

# %% [markdown]
# # TEST ENVIRONMENT

# %%
# episodes=1
# for i in range(episodes):
#     done=False
#     score=0   
#     state=env.reset()
#     while (not done):
#         action= env.action_space.sample()
#         state, reward, done, info = env.step(action)
#         score+=reward
#     print("Episode ", end='')
#     print(str(i+1)+': ', end='')
#     print(score)

# %% [markdown]
# # REINFORCEMENT LEARNING

# %% [markdown]
# ## Train

# %%
#for first time training
model = PPO('MultiInputPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=5000)
# Out:
# Logging to Training\Logs\PPO_1
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 844      |
# |    ep_rew_mean     | 25       |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 596      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 806          |
# |    ep_rew_mean          | 24.6         |
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 2            |
# |    time_elapsed         | 1197         |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0067000985 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | -0.0595      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00708     |
# |    value_loss           | 3.03         |
# ------------------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 811         |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 3           |
# |    time_elapsed         | 1791        |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004576107 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0936      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 2.28        |
# -----------------------------------------

# %% [markdown]
# ## Training Loop

# %%
model = PPO.load(save_Path, env=env)
for i in range(100):
    model.learn(total_timesteps=4000)
    model.save(save_Path)
    del model
    model = PPO.load(save_Path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_2
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 585      |
# |    ep_rew_mean     | 20       |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 601      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 574         |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1208        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009234153 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0483      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.482       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_3
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 566      |
# |    ep_rew_mean     | 22.3     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 602      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1215        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010402972 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.041       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.335       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_4
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 456      |
# |    ep_rew_mean     | 19.2     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 608      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 444         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1221        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010653431 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0467      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.216       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_5
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 367      |
# |    ep_rew_mean     | 16.8     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 617      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 404         |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1232        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010272851 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00817     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.244       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_6
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 440      |
# |    ep_rew_mean     | 19.5     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 609      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1237        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014709065 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 0.111       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_7
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 303      |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 622      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1244        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011862945 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 0.112       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_8
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 18       |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 621      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | 17.5        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1247        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012988497 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00884     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 0.105       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_9
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 245      |
# |    ep_rew_mean     | 16.1     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 633      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1272        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012403452 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00579    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 0.0801      |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_10
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 184      |
# |    ep_rew_mean     | 14.3     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 646      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1303        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011116089 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000514   |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 0.0996      |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_11
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 13.8     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 652      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 172        |
# |    ep_rew_mean          | 13.7       |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 2          |
# |    time_elapsed         | 1310       |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01265841 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.993     |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.011     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0295    |
# |    value_loss           | 0.0735     |
# ----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_12
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 13.4     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 666      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 13.6        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1324        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012824124 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0243     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 0.0615      |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_13
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 12.9     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 672      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1337        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011708823 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0195      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.0466      |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_14
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 12.9     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 680      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 2           |
# |    time_elapsed         | 1358        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011034925 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0328     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 0.0421      |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_15
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | 13.7     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 666      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | 13.6         |
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 2            |
# |    time_elapsed         | 1343         |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0100241825 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0211      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0134      |
# |    value_loss           | 0.0789       |
# ------------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_16
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 13.4     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 679      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ...
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0066      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.0185      |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_28
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 12.8     |
# | time/              |          |
# |    fps             | 2        |
# |    iterations      | 1        |
# |    time_elapsed    | 708      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 12.9        |
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 2           |
# |    time_elapsed         | 1421        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012392869 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.235      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000452   |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 0.015       |
# -----------------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_29
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | 12.8     |
# | time/              |          |
# |    fps             | 2        |
# |    iterations      | 1        |
# |    time_elapsed    | 708      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 model = PPO.load(save_Path, env=env)
#       2 for i in range(100):
# ----> 3     model.learn(total_timesteps=4000)
#       4     model.save(save_Path)
#       5     del model
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\on_policy_algorithm.py:194, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     189     else:
#     190         # Otherwise, clip the actions to avoid out of bound error
#     191         # as we are sampling from an unbounded Gaussian distribution
#     192         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 194 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     196 self.num_timesteps += env.num_envs
#     198 # Give access to local variables
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shimmy\openai_gym_compatibility.py:251, in GymV21CompatibilityV0.step(self, action)
#     242 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     243     """Steps through the environment.
#     244
#     245     Args:
#    (...)
#     249         (observation, reward, terminated, truncated, info)
#     250     """
# --> 251     obs, reward, done, info = self.gym_env.step(action)
#     253     if self.render_mode is not None:
#     254         self.render()
#
# Cell In[17], line 22, in tetrisEnv.step(self, action)
#      20 reward=0
#      21 #apply actions
# ---> 22 ACTIONS[action]()
#      23 if action==6:
#      24     if self.empty:
#
# Cell In[5], line 71, in hold()
#      70 def hold():
# ---> 71     pag.keyDown('c')
#      72     pag.keyUp('c')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyautogui\__init__.py:595, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     593 failSafeCheck()
#     594 returnVal = wrappedFunction(*args, **kwargs)
# --> 595 _handlePause(kwargs.get("_pause", True))
#     596 return returnVal
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyautogui\__init__.py:639, in _handlePause(_pause)
#     637 if _pause:
#     638     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 639     time.sleep(PAUSE)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save & Load

# %%
#save model
model.save(save_Path)

# %%
#delete model
del model

# %%
#load model
model = PPO.load(save_Path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # EVALUATION

# %%
evaluate_policy(model,env,n_eval_episodes=10, render=False)

# %% [markdown]
# # TEST MODEL

# %%
episodes=1
for i in range(episodes):
    done=False
    score=0   
    obs=env.reset()
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score+=reward
    print(score)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 28
